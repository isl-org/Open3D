# %%
import numpy as np
import matplotlib.pyplot as plt
im = np.load("build/t_frame.npy")
im = np.flip(im[:, :, :3], axis=2)
print(im.shape)
print(im.dtype)
plt.imshow(im)
# Out:
# (480, 640, 3)
# uint8
